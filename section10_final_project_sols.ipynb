# %% [markdown]
# # Final Project
#
# Ok, so today we'll be working with the transactions, product, and hh_demographic tables in the project_data folder.
#
# * First, read in the transactions data.
#
# * Read in the only columns `household_key`, `basket_id`, `DAY`, `QUANTITY`, and `SALES_VALUE`.
#
# * Convert `DAY`, `QUANTITY`, and `STORE_ID` to the smallest appropriate integer types.

# %%
import pandas as pd
import numpy as np

# %%
path = "../project_data/project_transactions.csv"

# specify columns to keep
cols = ["household_key", "BASKET_ID", "DAY", "PRODUCT_ID", "QUANTITY", "SALES_VALUE"]

# specify datatypes to convert
dtypes = {"DAY": "Int16", "QUANTITY": "Int32", "STORE_ID": "Int32"}

transactions = pd.read_csv(path,
                          dtype=dtypes,
                          usecols=cols)

# %%
transactions.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2146311 entries, 0 to 2146310
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   household_key  int64
#  1   BASKET_ID      int64
#  2   DAY            Int16
#  3   PRODUCT_ID     int64
#  4   QUANTITY       Int32
#  5   SALES_VALUE    float64
# dtypes: Int16(1), Int32(1), float64(1), int64(3)
# memory usage: 81.9 MB

# %%
# Use the following snippet to create a Date Column then drop. Then drop the `Day` and `Week_no` columns.

transactions = (transactions
                .assign(date = 
                        (pd.to_datetime("2016", format='%Y') 
                        + pd.to_timedelta(transactions["DAY"].sub(1).astype(str) + " days"))
                       )
                .drop(["DAY"], axis=1)
               )

# %%
transactions.head()
# Out:
#    household_key    BASKET_ID  PRODUCT_ID  QUANTITY  SALES_VALUE       date
# 0           1364  26984896261      842930         1         2.19 2016-01-01
# 1           1364  26984896261      897044         1         2.99 2016-01-01
# 2           1364  26984896261      920955         1         3.09 2016-01-01
# 3           1364  26984896261      937406         1         2.50 2016-01-01
# 4           1364  26984896261      981760         1         0.60 2016-01-01

# %% [markdown]
# ## TIME BASED ANALYSIS
#
# * Plot the sum of sales by month. Are sales growing over time?
# * Next, plot the same series after filtering down to dates April 2016 and October 2017.
# * Then, plot the sum of sales 2016 vs the 2017 sales.
# * Then, plot total sales by day of week.

# %%
# Set a date index, graby the sales column, and calculate a monthly sum using resampling.
# Then build the default line plot

(transactions.set_index("date")
 .loc[:, "SALES_VALUE"]
 .resample("M")
 .sum()
 .plot())
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# Filter above plot to specified date range with row slice in .loc
(transactions
 .set_index("date")
 .loc["2016-04":"2017-10", "SALES_VALUE"]
 .resample("M")
 .sum()
 .plot())
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# After resampling monthly sales, create a year_prior column with assign
# This column is our monthly sales shifted forward a year (12 rows/months)

(transactions
 .set_index("date")
 .loc[:, ["SALES_VALUE"]]
 .resample("M")
 .sum()
 .assign(year_prior = lambda x: x["SALES_VALUE"].shift(12))
 .loc["2017"]
 .plot())
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# Group transactions by dayofweek, then calculate sum and plot a bar chart
(transactions
 .groupby(transactions["date"].dt.dayofweek)
 .agg({"SALES_VALUE": "sum"})
 .plot.bar()
)
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# # DEMOGRAPHICS
#
# * Read in the `hh_demographic.csv` file, but only the columns `AGE_DESC`, `INCOME_DESC`, `household_key`, and `HH_COMP_DESC`. Convert the appropriate columns to the category dtype.
#
#
# * Then group the transactions table by household_id, and calculate the sum of SALES VALUE by household.
#
#
# * Once you've done that, join the demographics DataFrame to the transactions table. Since we're interested in analyzing the demographic data we have, make sure not to include rows from transactions that don't match.
#
#
# * Plot the sum of sales by age_desc and income_desc.
#
#
# * Then, create a pivot table of the mean household sales by `AGE_DESC` and `HH_COMP_DESC`. Which of our demographics have the highest average sales?

# %%
# Specify columns to include 
dem_cols = ["AGE_DESC", "INCOME_DESC", "household_key", "HH_COMP_DESC"]

# Convert the object columns here to category dtype
dem_dtypes = {"AGE_DESC": "category", "INCOME_DESC": "category", "HH_COMP_DESC":"category"}

demographics = pd.read_csv('../project_data/hh_demographic.csv',
                          usecols=dem_cols,
                          dtype=dem_dtypes
                          )

# %%
demographics.head()
# Out:
#   AGE_DESC INCOME_DESC      HH_COMP_DESC  household_key
# 0      65+      35-49K  2 Adults No Kids              1
# 1    45-54      50-74K  2 Adults No Kids              7
# 2    25-34      25-34K     2 Adults Kids              8
# 3    25-34      75-99K     2 Adults Kids             13
# 4    45-54      50-74K     Single Female             16

# %%
demographics.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   AGE_DESC       801 non-null    category
#  1   INCOME_DESC    801 non-null    category
#  2   HH_COMP_DESC   801 non-null    category
#  3   household_key  801 non-null    int64
# dtypes: category(3), int64(1)
# memory usage: 10.9 KB

# %%
# Create total sales by household dataframe

household_sales = (transactions
                   .groupby("household_key")
                   .agg({"SALES_VALUE": "sum"})
                  )

household_sales
# Out:
#                SALES_VALUE
# household_key
# 1                  4330.16
# 2                  1954.34
# 3                  2653.21
# 4                  1200.11
# 5                   779.06
# ...                    ...
# 2095               3790.49
# 2096               1301.65
# 2097               8823.83
# 2098                682.46
# 2099                691.30
#
# [2099 rows x 1 columns]

# %%
# Join household sales and demographics table on household_key (inner since we're interested in both sets)

household_sales_demo = (household_sales.merge(demographics, 
                             how="inner",
                             left_on='household_key',
                             right_on="household_key",
                             )
                       )

# %%
household_sales_demo.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 668 entries, 0 to 667
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   household_key  668 non-null    int64
#  1   SALES_VALUE    668 non-null    float64
#  2   AGE_DESC       668 non-null    category
#  3   INCOME_DESC    668 non-null    category
#  4   HH_COMP_DESC   668 non-null    category
# dtypes: category(3), float64(1), int64(1)
# memory usage: 19.8 KB

# %%
# Calculate sum of sales by age group

(household_sales_demo
.groupby(["AGE_DESC"])
.agg({"SALES_VALUE": "sum"})
.plot.bar()
)
# Out:
# <AxesSubplot:xlabel='AGE_DESC'>

# %%
# Calculate sum of sales by income, ordered by magnitude

(household_sales_demo.groupby(["INCOME_DESC"])
.agg({"SALES_VALUE": "sum"})
.sort_values("SALES_VALUE", ascending=False)
.plot.bar())
# Out:
# <AxesSubplot:xlabel='INCOME_DESC'>

# %%
# Calculate mean household spend by Age Description and HH Composition
# Format with a heatmap across all cells

(household_sales_demo.pivot_table(index="AGE_DESC", 
                 columns="HH_COMP_DESC",
                 values="SALES_VALUE",
                 aggfunc="mean",
                 margins=True)
 .style.background_gradient(cmap="RdYlGn", axis=None)
)
# Out:
# <style type="text/css">
# #T_a5882_row0_col0 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_a5882_row0_col1, #T_a5882_row1_col6 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_a5882_row0_col2 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_a5882_row0_col3 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_a5882_row0_col4 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_a5882_row0_col5, #T_a5882_row1_col4 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_a5882_row0_col6, #T_a5882_row4_col1 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_a5882_row1_col0 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_a5882_row1_col1, #T_a5882_row4_col2 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_a5882_row1_col2 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_a5882_row1_col3 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_a5882_row1_col5 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_a5882_row2_col0 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_a5882_row2_col1 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_a5882_row2_col2 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_a5882_row2_col3 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_a5882_row2_col4, #T_a5882_row3_col5 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_a5882_row2_col5 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_a5882_row2_col6 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_a5882_row3_col0 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_a5882_row3_col1 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_a5882_row3_col2 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_a5882_row3_col3, #T_a5882_row6_col4 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_a5882_row3_col4 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_a5882_row3_col6, #T_a5882_row5_col1 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_a5882_row4_col0 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_a5882_row4_col3 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_a5882_row4_col4 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_a5882_row4_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_a5882_row4_col6 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_a5882_row5_col0 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_a5882_row5_col2 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_a5882_row5_col3 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_a5882_row5_col4 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_a5882_row5_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_a5882_row5_col6 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_a5882_row6_col0 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_a5882_row6_col1 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_a5882_row6_col2 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_a5882_row6_col3 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_a5882_row6_col5 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_a5882_row6_col6 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# </style>
# <table id="T_a5882_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >HH_COMP_DESC</th>
#       <th class="col_heading level0 col0" >1 Adult Kids</th>
#       <th class="col_heading level0 col1" >2 Adults Kids</th>
#       <th class="col_heading level0 col2" >2 Adults No Kids</th>
#       <th class="col_heading level0 col3" >Single Female</th>
#       <th class="col_heading level0 col4" >Single Male</th>
#       <th class="col_heading level0 col5" >Unknown</th>
#       <th class="col_heading level0 col6" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >AGE_DESC</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5882_level0_row0" class="row_heading level0 row0" >19-24</th>
#       <td id="T_a5882_row0_col0" class="data row0 col0" >7268.796667</td>
#       <td id="T_a5882_row0_col1" class="data row0 col1" >5428.945000</td>
#       <td id="T_a5882_row0_col2" class="data row0 col2" >4020.800000</td>
#       <td id="T_a5882_row0_col3" class="data row0 col3" >4576.095556</td>
#       <td id="T_a5882_row0_col4" class="data row0 col4" >3216.835000</td>
#       <td id="T_a5882_row0_col5" class="data row0 col5" >4911.275000</td>
#       <td id="T_a5882_row0_col6" class="data row0 col6" >4692.077692</td>
#     </tr>
#     <tr>
#       <th id="T_a5882_level0_row1" class="row_heading level0 row1" >25-34</th>
#       <td id="T_a5882_row1_col0" class="data row1 col0" >5512.196875</td>
#       <td id="T_a5882_row1_col1" class="data row1 col1" >5753.973514</td>
#       <td id="T_a5882_row1_col2" class="data row1 col2" >5638.515833</td>
#       <td id="T_a5882_row1_col3" class="data row1 col3" >4807.440588</td>
#       <td id="T_a5882_row1_col4" class="data row1 col4" >4909.522381</td>
#       <td id="T_a5882_row1_col5" class="data row1 col5" >7356.270000</td>
#       <td id="T_a5882_row1_col6" class="data row1 col6" >5435.517521</td>
#     </tr>
#     <tr>
#       <th id="T_a5882_level0_row2" class="row_heading level0 row2" >35-44</th>
#       <td id="T_a5882_row2_col0" class="data row2 col0" >6297.737778</td>
#       <td id="T_a5882_row2_col1" class="data row2 col1" >6691.772264</td>
#       <td id="T_a5882_row2_col2" class="data row2 col2" >6260.412444</td>
#       <td id="T_a5882_row2_col3" class="data row2 col3" >6015.192069</td>
#       <td id="T_a5882_row2_col4" class="data row2 col4" >4844.192000</td>
#       <td id="T_a5882_row2_col5" class="data row2 col5" >4227.691818</td>
#       <td id="T_a5882_row2_col6" class="data row2 col6" >6090.556728</td>
#     </tr>
#     <tr>
#       <th id="T_a5882_level0_row3" class="row_heading level0 row3" >45-54</th>
#       <td id="T_a5882_row3_col0" class="data row3 col0" >6632.569167</td>
#       <td id="T_a5882_row3_col1" class="data row3 col1" >6610.484490</td>
#       <td id="T_a5882_row3_col2" class="data row3 col2" >5839.527027</td>
#       <td id="T_a5882_row3_col3" class="data row3 col3" >4549.365405</td>
#       <td id="T_a5882_row3_col4" class="data row3 col4" >4636.637083</td>
#       <td id="T_a5882_row3_col5" class="data row3 col5" >4843.995682</td>
#       <td id="T_a5882_row3_col6" class="data row3 col6" >5534.879958</td>
#     </tr>
#     <tr>
#       <th id="T_a5882_level0_row4" class="row_heading level0 row4" >55-64</th>
#       <td id="T_a5882_row4_col0" class="data row4 col0" >3064.870000</td>
#       <td id="T_a5882_row4_col1" class="data row4 col1" >4695.655000</td>
#       <td id="T_a5882_row4_col2" class="data row4 col2" >5752.413684</td>
#       <td id="T_a5882_row4_col3" class="data row4 col3" >4816.148462</td>
#       <td id="T_a5882_row4_col4" class="data row4 col4" >3922.546250</td>
#       <td id="T_a5882_row4_col5" class="data row4 col5" >7973.750000</td>
#       <td id="T_a5882_row4_col6" class="data row4 col6" >5168.924200</td>
#     </tr>
#     <tr>
#       <th id="T_a5882_level0_row5" class="row_heading level0 row5" >65+</th>
#       <td id="T_a5882_row5_col0" class="data row5 col0" >4040.810000</td>
#       <td id="T_a5882_row5_col1" class="data row5 col1" >5536.866667</td>
#       <td id="T_a5882_row5_col2" class="data row5 col2" >4614.108571</td>
#       <td id="T_a5882_row5_col3" class="data row5 col3" >4059.699412</td>
#       <td id="T_a5882_row5_col4" class="data row5 col4" >3871.556000</td>
#       <td id="T_a5882_row5_col5" class="data row5 col5" >2879.290000</td>
#       <td id="T_a5882_row5_col6" class="data row5 col6" >4340.936500</td>
#     </tr>
#     <tr>
#       <th id="T_a5882_level0_row6" class="row_heading level0 row6" >All</th>
#       <td id="T_a5882_row6_col0" class="data row6 col0" >6032.802143</td>
#       <td id="T_a5882_row6_col1" class="data row6 col1" >6280.069103</td>
#       <td id="T_a5882_row6_col2" class="data row6

# %%
# delete dfs we won't use anymore

del [household_sales_demo, household_sales]

# %% [markdown]
# # PRODUCT DEMOGRAPHICS
#
# * Read in the product csv file.
#
# * Only read in product_id and department from product (consider converting columns).
#
# * Join the product DataFrame to transactions and demographics tables, performing an inner join when joining both tables.
#
# * Finally, pivot the fully joined dataframe by AGE_DESC and DEPARTMENT, calculating the sum of sales. Which category does our youngest demographic perform well in?

# %%
# specify columns to use
product_cols = ["PRODUCT_ID", "DEPARTMENT"]

# specify datatypes for each column
product_dtypes = {"PRODUCT_ID": "Int32", "DEPARTMENT": "category"}

product = pd.read_csv('../project_data/product.csv',
                     usecols=product_cols,
                     dtype=product_dtypes)

# %%
product.dtypes
# Out:
# PRODUCT_ID       Int32
# DEPARTMENT    category
# dtype: object

# %%
# Join all three tables together with an inner join
# Join product on product_id (only shared column)
trans_demo_dept = (transactions
                  .merge(demographics, 
                         how="inner",
                         left_on='household_key',
                         right_on="household_key",)
                  .merge(product,
                         how="inner",
                         left_on="PRODUCT_ID",
                         right_on="PRODUCT_ID")
             
             )

# %%
# much smaller than our original, uncoverted transactions df!
trans_demo_dept.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1161575 entries, 0 to 1161574
# Data columns (total 10 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   household_key  1161575 non-null  int64
#  1   BASKET_ID      1161575 non-null  int64
#  2   PRODUCT_ID     1161575 non-null  int64
#  3   QUANTITY       1161575 non-null  Int32
#  4   SALES_VALUE    1161575 non-null  float64
#  5   date           1161575 non-null  datetime64[ns]
#  6   AGE_DESC       1161575 non-null  category
#  7   INCOME_DESC    1161575 non-null  category
#  8   HH_COMP_DESC   1161575 non-null  category
#  9   DEPARTMENT     1161575 non-null  category
# dtypes: Int32(1), category(4), datetime64[ns](1), float64(1), int64(3)
# memory usage: 63.1 MB

# %%
# Where does our youngest demographic rank near the top in sales?

(trans_demo_dept.pivot_table(index="DEPARTMENT",
                            columns="AGE_DESC",
                            values="SALES_VALUE",
                            aggfunc="sum")
 .style.background_gradient(cmap="RdYlGn", axis=1))
# Out:
# <style type="text/css">
# #T_f319c_row0_col0, #T_f319c_row0_col1, #T_f319c_row0_col2, #T_f319c_row0_col3, #T_f319c_row0_col4, #T_f319c_row0_col5, #T_f319c_row1_col4, #T_f319c_row2_col0, #T_f319c_row2_col1, #T_f319c_row2_col2, #T_f319c_row2_col3, #T_f319c_row2_col4, #T_f319c_row2_col5, #T_f319c_row3_col0, #T_f319c_row3_col4, #T_f319c_row4_col1, #T_f319c_row5_col5, #T_f319c_row6_col0, #T_f319c_row7_col5, #T_f319c_row8_col0, #T_f319c_row9_col0, #T_f319c_row9_col1, #T_f319c_row9_col4, #T_f319c_row10_col0, #T_f319c_row11_col0, #T_f319c_row11_col1, #T_f319c_row11_col2, #T_f319c_row11_col3, #T_f319c_row11_col4, #T_f319c_row11_col5, #T_f319c_row12_col0, #T_f319c_row13_col0, #T_f319c_row14_col0, #T_f319c_row15_col0, #T_f319c_row15_col1, #T_f319c_row16_col0, #T_f319c_row16_col1, #T_f319c_row16_col2, #T_f319c_row16_col4, #T_f319c_row16_col5, #T_f319c_row17_col0, #T_f319c_row18_col0, #T_f319c_row18_col1, #T_f319c_row18_col2, #T_f319c_row18_col3, #T_f319c_row18_col4, #T_f319c_row18_col5, #T_f319c_row19_col0, #T_f319c_row19_col1, #T_f319c_row19_col2, #T_f319c_row19_col3, #T_f319c_row19_col4, #T_f319c_row19_col5, #T_f319c_row20_col0, #T_f319c_row21_col0, #T_f319c_row22_col0, #T_f319c_row22_col5, #T_f319c_row23_col0, #T_f319c_row23_col1, #T_f319c_row23_col5, #T_f319c_row24_col0, #T_f319c_row25_col0, #T_f319c_row26_col0, #T_f319c_row27_col0, #T_f319c_row28_col0, #T_f319c_row28_col4, #T_f319c_row28_col5, #T_f319c_row29_col4, #T_f319c_row30_col0, #T_f319c_row30_col1, #T_f319c_row30_col2, #T_f319c_row30_col3, #T_f319c_row30_col4, #T_f319c_row30_col5, #T_f319c_row31_col0, #T_f319c_row31_col1, #T_f319c_row31_col2, #T_f319c_row32_col0, #T_f319c_row32_col1, #T_f319c_row32_col4, #T_f319c_row32_col5, #T_f319c_row33_col0, #T_f319c_row34_col0, #T_f319c_row35_col0, #T_f319c_row35_col1, #T_f319c_row35_col4, #T_f319c_row36_col4, #T_f319c_row37_col0, #T_f319c_row38_col0, #T_f319c_row39_col5, #T_f319c_row40_col0, #T_f319c_row40_col1, #T_f319c_row40_col2, #T_f319c_row40_col4, #T_f319c_row40_col5, #T_f319c_row41_col0, #T_f319c_row42_col0, #T_f319c_row42_col3, #T_f319c_row42_col4, #T_f319c_row42_col5, #T_f319c_row43_col0, #T_f319c_row43_col1, #T_f319c_row43_col2, #T_f319c_row43_col3, #T_f319c_row43_col4, #T_f319c_row43_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_f319c_row1_col0, #T_f319c_row27_col5 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# #T_f319c_row1_col1, #T_f319c_row36_col1 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_f319c_row1_col2, #T_f319c_row3_col3, #T_f319c_row4_col3, #T_f319c_row5_col3, #T_f319c_row6_col3, #T_f319c_row7_col3, #T_f319c_row8_col3, #T_f319c_row9_col2, #T_f319c_row10_col3, #T_f319c_row12_col3, #T_f319c_row13_col2, #T_f319c_row14_col3, #T_f319c_row15_col3, #T_f319c_row16_col3, #T_f319c_row17_col3, #T_f319c_row20_col3, #T_f319c_row21_col3, #T_f319c_row22_col3, #T_f319c_row23_col3, #T_f319c_row24_col3, #T_f319c_row25_col2, #T_f319c_row26_col3, #T_f319c_row27_col3, #T_f319c_row28_col1, #T_f319c_row29_col2, #T_f319c_row31_col3, #T_f319c_row32_col3, #T_f319c_row33_col3, #T_f319c_row34_col3, #T_f319c_row35_col2, #T_f319c_row35_col3, #T_f319c_row36_col3, #T_f319c_row37_col3, #T_f319c_row38_col3, #T_f319c_row39_col3, #T_f319c_row40_col3, #T_f319c_row41_col3, #T_f319c_row42_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_f319c_row1_col3, #T_f319c_row6_col2, #T_f319c_row13_col3 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_f319c_row1_col5, #T_f319c_row6_col4, #T_f319c_row9_col3 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_f319c_row3_col1, #T_f319c_row8_col5 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_f319c_row3_col2 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_f319c_row3_col5, #T_f319c_row4_col0, #T_f319c_row4_col4 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_f319c_row4_col2 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_f319c_row4_col5 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_f319c_row5_col0 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_f319c_row5_col1, #T_f319c_row33_col1 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_f319c_row5_col2 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_f319c_row5_col4, #T_f319c_row38_col5 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_f319c_row6_col1 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_f319c_row6_col5, #T_f319c_row20_col4, #T_f319c_row26_col4 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_f319c_row7_col0 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_f319c_row7_col1, #T_f319c_row26_col5, #T_f319c_row33_col4 {
#   background-color: #e0422f;
#   color: #f1f1f1;
# }
# #T_f319c_row7_col2, #T_f319c_row24_col2 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_f319c_row7_col4, #T_f319c_row41_col4 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_f319c_row8_col1 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_f319c_row8_col2, #T_f319c_row39_col1 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_f319c_row8_col4, #T_f319c_row14_col4 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_f319c_row9_col5 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_f319c_row10_col1, #T_f319c_row15_col4, #T_f319c_row22_col1 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_f319c_row10_col2, #T_f319c_row28_col2, #T_f319c_row33_col2 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_f319c_row10_col4 {
#   background-color: #b10b26;
#   color: #f1f1f1;
# }
# #T_f319c_row10_col5, #T_f319c_row17_col4 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_f319c_row12_col1 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_f319c_row12_col2 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_f319c_row12_col4, #T_f319c_row25_col5, #T_f319c_row31_col5 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_f319c_row12_col5 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_f319c_row13_col1, #T_f319c_row20_col1 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_f319c_row13_col4 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_f319c_row13_col5, #T_f319c_row37_col5, #T_f319c_row38_col4 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_f319c_row14_col1 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_f319c_row14_col2 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_f319c_row14_col5 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_f319c_row15_col2 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_f319c_row15_col5 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_f319c_row17_col1 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_f319c_row17_col2 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_f319c_row17_col5, #T_f319c_row34_col5 {
#   background-color: #be1827;
#   color: #f1f1f1;
# }
# #T_f319c_row20_col2 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_f319c_row20_col5, #T_f319c_row21_col4 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_f319c_row21_col1, #T_f319c_row28_col3 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_f319c_row21_col2, #T_f319c_row26_col1 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_f319c_row21_col5, #T_f319c_row27_col4 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_f319c_row22_col2 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_f319c_row22_col4, #T_f319c_row24_col5 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_f319c_row23_col2, #T_f319c_row23_col4 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_f319c_row24_col1 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_f319c_row24_col4 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_f319c_row25_col1 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_f319c_row25_col3 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_f319c_row25_col4 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_f319c_row26_col2 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_f319c_row27_col1 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_f319c_row27_col2 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_f319c_row29_col0 {
#   background-col

# %% [markdown]
# # EXPORT
#
# Finally, export your pivot table to an excel file. Make sure to provide a sheet name.

# %%
# Call to_excel on pivot table above - note the formatting gets passed to excel too!

(trans_demo_dept.pivot_table(index="DEPARTMENT",
                            columns="AGE_DESC",
                            values="SALES_VALUE",
                            aggfunc="sum")
 .style.background_gradient(cmap="RdYlGn", axis=1)
 .to_excel("demographic_category_sales.xlsx", sheet_name="sales_pivot")
)
